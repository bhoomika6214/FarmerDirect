# %% [markdown]
# <a href="https://colab.research.google.com/github/bhoomika6214/FarmerDirect/blob/main/pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("//content//Orders.csv")
df.head(10)
# Out:
#   Order ID  Order Date CustomerName           State       City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh    Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi      Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh    Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra     Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh     Indore
# 5  B-25967  21-01-2018       Sudevi   Uttar Pradesh  Prayagraj
# 6  B-25955  16-01-2018        Shiva     Maharashtra       Pune
# 7  B-26093  27-03-2018       Sarita     Maharashtra       Pune
# 8  B-25798  01-10-2018       Shishu  Andhra Pradesh  Hyderabad
# 9  B-25602  01-04-2018       Vrinda     Maharashtra       Pune

# %%
list=[1,'Bhoomika',80000,'CSE','karnataka','hassan',15000],[2,'Nidhi',60000,'CSE','karnataka','hassan',15000],[3,'Thanu',50000,'CSE','karnataka','hassan',15000]
df1=pd.DataFrame(list)

# %%
df1.columns=['empid','name','salary','department','state','place','increment']
df1
# Out:
#    empid      name  salary department      state   place  increment
# 0      1  Bhoomika   80000        CSE  karnataka  hassan      15000
# 1      2     Nidhi   60000        CSE  karnataka  hassan      15000
# 2      3     Thanu   50000        CSE  karnataka  hassan      15000

# %%
empcolumns=df1.columns
empcolumns
# Out:
# Index(['empid', 'name', 'salary', 'department', 'state', 'place', 'increment'], dtype='object')

# %%
empdata=df1.values
print(empdata)
# Out:
# [[1 'Bhoomika' 80000 'CSE' 'karnataka' 'hassan' 15000]
#  [2 'Nidhi' 60000 'CSE' 'karnataka' 'hassan' 15000]
#  [3 'Thanu' 50000 'CSE' 'karnataka' 'hassan' 15000]]

# %%
ArraytoDf=pd.DataFrame(empdata,columns=empcolumns)
ArraytoDf
# Out:
#   empid      name salary department      state   place increment
# 0     1  Bhoomika  80000        CSE  karnataka  hassan     15000
# 1     2     Nidhi  60000        CSE  karnataka  hassan     15000
# 2     3     Thanu  50000        CSE  karnataka  hassan     15000

# %%
def calo_SalofInc(salary):
  inc=0
  if salary<50000:
    inc=salary*30/100
  else:
    inc=salary*10/100
  return inc
print(calo_SalofInc(35000))
calo_SalofInc(5000)
# Out:
# 10500.0
# 1500.0

# %%
df1['Increment']=df1['salary'].apply(calo_SalofInc)
df1
# Out:
#    empid      name  salary department      state   place  increment  Increment
# 0      1  Bhoomika   80000        CSE  karnataka  hassan      15000     8000.0
# 1      2     Nidhi   60000        CSE  karnataka  hassan      15000     6000.0
# 2      3     Thanu   50000        CSE  karnataka  hassan      15000     5000.0

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
df1.rename(columns={'department':'emp_department'},inplace=True)
df1
# Out:
#    empid      name  salary emp_department      state   place  increment  \
# 0      1  Bhoomika   80000            CSE  karnataka  hassan      15000
# 1      2     Nidhi   60000            CSE  karnataka  hassan      15000
# 2      3     Thanu   50000            CSE  karnataka  hassan      15000
#
#    Increment
# 0     8000.0
# 1     6000.0
# 2     5000.0

# %%
# Calculate the mean of the 'salary' column.
df1.salary.mean()
# Out:
# 63333.333333333336
